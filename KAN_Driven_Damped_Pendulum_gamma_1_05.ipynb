# %% [markdown]
# ## Solution of a Driven Damped Pendulum using a Kolmogorov-Arnold Network (KAN)
#
# ***Author: Brandon Ismalej (brandon.ismalej.671@my.csun.edu) - (https://github.com/Brandon-Ism)***

# %%
# !pip install pykan torch numpy matplotlib scikit-learn tqdm sympy setuptools
# Out:
# Collecting pykan
#   Downloading pykan-0.2.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.1.2+cpu)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (1.2.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (4.66.4)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (1.13.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (69.0.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch) (4.9.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2024.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.3.2 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy) (1.3.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Downloading pykan-0.2.4-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 3.6 MB/s eta 0:00:00
# Installing collected packages: pykan
# Successfully installed pykan-0.2.4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp
import torch
import torch.nn as nn
from torch import autograd
from kan import KAN
import math
import os

# %%
from sympy import symbols, Function
gamma_sym = symbols('gamma')
gamma_func = Function('gamma')

# Clear previous definitions
del gamma_sym
del gamma_func

# %%
# Initialize Constants
Omega_val = 2 * np.pi  
omega_val = Omega_val * 1.5 
lambda_val = omega_val / 2 
gamma_val = 1.05
omegaSQ_val = omega_val ** 2
f_val = gamma_val * omegaSQ_val

# %%
# This is the function for scipy odeint that helps it to solve the diff equation
# Differential equation
def helper(t, theta):
    theta, z = theta
    dthetadt = [z, f_val * math.cos(Omega_val * t) - omegaSQ_val * math.sin(theta) - lambda_val * z]
    return dthetadt

# %%
# Define the driven damped pendulum differential equation
#def driven_damped_pendulum(t, y, omega, lambda_, gamma, Omega):
#    theta, omega_dot = y
#   dydt = [omega_dot, -lambda_ * omega_dot - omega**2 * np.sin(theta) + gamma * np.cos(Omega * t)]
 #   return dydt

# Initial conditions
initial_conditions = [0, 0]
start_val = 0
end_val = 15

# Time points
t = np.linspace(start_val, end_val, 3000)

# Solve the differential equation using solve_ivp
sol = solve_ivp(helper, [start_val, end_val], initial_conditions, t_eval=t, method='LSODA', rtol=1e-6, atol=1e-8)

# Solve the differential equation using solve_ivp
# sol = solve_ivp(driven_damped_pendulum, [t[0], t[-1]], y0, args=(omega_val, lambda_val, gamma_val, Omega_val), t_eval=t, method='LSODA', rtol=1e-6, atol=1e-8)

# %%
plt.figure(figsize=(12, 8))
plt.plot(sol.t, sol.y[0], label='Numerical Solution')
plt.xlabel('t')
plt.ylabel('phi(t) ')
plt.grid(True)
plt.savefig('numerical_only.png')
plt.show()

# %%
# Save ODE solver results to CSV
ode_df = pd.DataFrame({'t': sol.t, 'theta': sol.y[0], 'omega_dot': sol.y[1]})
ode_df.to_csv('ode_solver_results.csv', index=False)

# %%
# Define a separate time interval for the neural network training
nn_start_val = 0
nn_end_val = 15
nn_t = np.linspace(nn_start_val, nn_end_val, 12000)

# Prepare training data based on the new time interval
x_physics = torch.tensor(nn_t, dtype=torch.float32).view(-1, 1)
y_physics = torch.tensor(np.interp(nn_t, t, sol.y[0]), dtype=torch.float32).view(-1, 1)

# %%
print({type(x_physics)})
# Out:
# {<class 'torch.Tensor'>}

# %%
from kan import *

physics_weight = 1e-3

# Define the KAN model
model = KAN(width=[1,4,4,1], grid=5, k=3, seed=0)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2)
criterion = nn.MSELoss()
# Out:
# checkpoint directory created: ./model
# saving model version 0.0

# %%
# Convert to torch.Tensor
Omega = torch.tensor(Omega_val, dtype=torch.float32)
omega = torch.tensor(omega_val, dtype=torch.float32)
lambda_ = torch.tensor(lambda_val, dtype=torch.float32)
gamma = torch.tensor(gamma_val, dtype=torch.float32)  
omegaSQ = torch.tensor(omegaSQ_val, dtype=torch.float32)
f = torch.tensor(f_val, dtype=torch.float32)

# %%
# Training loop
epochs = 25000
losses = {'total_loss': [], 'boundary_loss': [], 'physics_loss': []}
patience = 3000  
best_loss = float('inf')
early_stop_counter = 0
best_model_state = None
best_epoch = -1 

for epoch in range(epochs):
    optimizer.zero_grad()
    
    # Forward pass
    outputs = model(x_physics)
    
    # Compute boundary loss (initial condition)
    boundary_loss = criterion(outputs[0], torch.tensor([initial_conditions[0]], dtype=torch.float32))
    
    # For simplicity, we'll consider physics loss as the total loss in this context
    physics_loss = criterion(outputs, y_physics)
    
    # Total loss
    total_loss = boundary_loss + physics_loss
    total_loss.backward()
    optimizer.step()
    
    losses['total_loss'].append(total_loss.item())
    losses['boundary_loss'].append(boundary_loss.item())
    losses['physics_loss'].append(physics_loss.item())
    
    # Early stopping logic and model state saving
    if total_loss.item() < best_loss:
        best_loss = total_loss.item()
        early_stop_counter = 0
        # Save the best model state
        best_model_state = model.state_dict()
        best_epoch = epoch  # Save the epoch number
    else:
        early_stop_counter += 1

    if early_stop_counter > patience:
        print(f"Early stopping at epoch {epoch+1}")
        break

    # Print progress
    if (epoch+1) % 100 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Total Loss: {total_loss.item():.4f}')

# Restore the best model state after training
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    print(f'Restored model to epoch {best_epoch+1} with best loss: {best_loss:.4f}')
# Out:
# Epoch [100/25000], Total Loss: 14.0887
# Epoch [200/25000], Total Loss: 3.0086
# Epoch [300/25000], Total Loss: 2.9286
# Epoch [400/25000], Total Loss: 2.8790
# Epoch [500/25000], Total Loss: 2.8483
# Epoch [600/25000], Total Loss: 2.8233
# Epoch [700/25000], Total Loss: 2.7983
# Epoch [800/25000], Total Loss: 2.7721
# Epoch [900/25000], Total Loss: 2.7401
# Epoch [1000/25000], Total Loss: 2.7078
# Epoch [1100/25000], Total Loss: 2.6804
# Epoch [1200/25000], Total Loss: 2.6571
# Epoch [1300/25000], Total Loss: 2.6375
# Epoch [1400/25000], Total Loss: 2.6164
# Epoch [1500/25000], Total Loss: 2.3991
# Epoch [1600/25000], Total Loss: 1.9999
# Epoch [1700/25000], Total Loss: 1.8953
# Epoch [1800/25000], Total Loss: 1.8621
# Epoch [1900/25000], Total Loss: 1.8380
# Epoch [2000/25000], Total Loss: 1.8336
# Epoch [2100/25000], Total Loss: 1.7955
# Epoch [2200/25000], Total Loss: 1.7803
# Epoch [2300/25000], Total Loss: 1.7642
# Epoch [2400/25000], Total Loss: 1.7488
# Epoch [2500/25000], Total Loss: 1.7773
# Epoch [2600/25000], Total Loss: 1.7356
# Epoch [2700/25000], Total Loss: 1.7265
# Epoch [2800/25000], Total Loss: 1.7432
# Epoch [2900/25000], Total Loss: 1.7487
# Epoch [3000/25000], Total Loss: 1.7151
# Epoch [3100/25000], Total Loss: 1.7249
# Epoch [3200/25000], Total Loss: 1.7268
# Epoch [3300/25000], Total Loss: 1.7056
# Epoch [3400/25000], Total Loss: 1.7042
# Epoch [3500/25000], Total Loss: 1.7017
# Epoch [3600/25000], Total Loss: 1.7101
# Epoch [3700/25000], Total Loss: 1.7053
# Epoch [3800/25000], Total Loss: 1.6984
# Epoch [3900/25000], Total Loss: 1.7175
# Epoch [4000/25000], Total Loss: 1.6955
# Epoch [4100/25000], Total Loss: 1.6965
# Epoch [4200/25000], Total Loss: 1.6944
# Epoch [4300/25000], Total Loss: 1.6929
# Epoch [4400/25000], Total Loss: 1.6936
# Epoch [4500/25000], Total Loss: 1.6915
# Epoch [4600/25000], Total Loss: 1.6904
# Epoch [4700/25000], Total Loss: 1.6963
# Epoch [4800/25000], Total Loss: 1.6875
# Epoch [4900/25000], Total Loss: 1.6864
# Epoch [5000/25000], Total Loss: 1.6865
# Epoch [5100/25000], Total Loss: 1.6844
# Epoch [5200/25000], Total Loss: 1.6822
# Epoch [5300/25000], Total Loss: 2.6985
# Epoch [5400/25000], Total Loss: 1.6976
# Epoch [5500/25000], Total Loss: 1.6889
# Epoch [5600/25000], Total Loss: 1.6846
# Epoch [5700/25000], Total Loss: 1.6812
# Epoch [5800/25000], Total Loss: 1.6748
# Epoch [5900/25000], Total Loss: 1.6765
# Epoch [6000/25000], Total Loss: 1.7055
# Epoch [6100/25000], Total Loss: 1.7018
# Epoch [6200/25000], Total Loss: 1.6893
# Epoch [6300/25000], Total Loss: 1.6959
# Epoch [6400/25000], Total Loss: 1.6879
# Epoch [6500/25000], Total Loss: 1.7106
# Epoch [6600/25000], Total Loss: 1.6772
# Epoch [6700/25000], Total Loss: 1.6887
# Epoch [6800/25000], Total Loss: 1.6729
# Epoch [6900/25000], Total Loss: 1.6738
# Epoch [7000/25000], Total Loss: 1.6584
# Epoch [7100/25000], Total Loss: 1.6459
# Epoch [7200/25000], Total Loss: 2.1771
# Epoch [7300/25000], Total Loss: 1.8065
# Epoch [7400/25000], Total Loss: 1.5888
# Epoch [7500/25000], Total Loss: 1.4825
# Epoch [7600/25000], Total Loss: 1.4184
# Epoch [7700/25000], Total Loss: 1.3774
# Epoch [7800/25000], Total Loss: 1.3400
# Epoch [7900/25000], Total Loss: 1.2936
# Epoch [8000/25000], Total Loss: 1.3220
# Epoch [8100/25000], Total Loss: 1.2660
# Epoch [8200/25000], Total Loss: 1.2632
# Epoch [8300/25000], Total Loss: 1.2575
# Epoch [8400/25000], Total Loss: 1.2534
# Epoch [8500/25000], Total Loss: 1.3202
# Epoch [8600/25000], Total Loss: 1.2460
# Epoch [8700/25000], Total Loss: 1.2438
# Epoch [8800/25000], Total Loss: 1.2480
# Epoch [8900/25000], Total Loss: 1.2376
# Epoch [9000/25000], Total Loss: 1.2485
# Epoch [9100/25000], Total Loss: 1.2721
# Epoch [9200/25000], Total Loss: 1.2394
# Epoch [9300/25000], Total Loss: 1.2334
# Epoch [9400/25000], Total Loss: 1.2368
# Epoch [9500/25000], Total Loss: 1.3300
# Epoch [9600/25000], Total Loss: 1.3944
# Epoch [9700/25000], Total Loss: 1.2734
# Epoch [9800/25000], Total Loss: 1.2341
# Epoch [9900/25000], Total Loss: 1.3435
# Epoch [10000/25000], Total Loss: 1.1947
# Epoch [10100/25000], Total Loss: 1.2377
# Epoch [10200/25000], Total Loss: 1.2320
# Epoch [10300/25000], Total Loss: 1.2258
# Epoch [10400/25000], Total Loss: 1.2346
# Epoch [10500/25000], Total Loss: 1.2186
# Epoch [10600/25000], Total Loss: 1.2270
# Epoch [10700/25000], Total Loss: 1.2148
# Epoch [10800/25000], Total Loss: 1.2996
# Epoch [10900/25000], Total Loss: 1.2158
# Epoch [11000/25000], Total Loss: 1.2052
# Epoch [11100/25000], Total Loss: 1.2002
# Epoch [11200/25000], Total Loss: 1.1967
# Epoch [11300/25000], Total Loss: 1.2021
# Epoch [11400/25000], Total Loss: 1.1940
# Epoch [11500/25000], Total Loss: 1.2153
# Epoch [11600/25000], Total Loss: 1.1882
# Epoch [11700/25000], Total Loss: 1.1910
# Epoch [11800/25000], Total Loss: 1.1892
# Epoch [11900/25000], Total Loss: 1.1876
# Epoch [12000/25000], Total Loss: 1.1802
# Epoch [12100/25000], Total Loss: 1.1903
# Epoch [12200/25000], Total Loss: 1.2552
# Epoch [12300/25000], Total Loss: 1.1879
# Epoch [12400/25000], Total Loss: 1.2041
# Epoch [12500/25000], Total Loss: 1.1745
# Epoch [12600/25000], Total Loss: 1.1743
# Epoch [12700/25000], Total Loss: 1.1429
# Epoch [12800/25000], Total Loss: 1.1311
# Epoch [12900/25000], Total Loss: 1.1352
# Epoch [13000/25000], Total Loss: 1.0903
# Epoch [13100/25000], Total Loss: 1.0858
# Epoch [13200/25000], Total Loss: 1.0843
# Epoch [13300/25000], Total Loss: 1.0527
# Epoch [13400/25000], Total Loss: 1.0483
# Epoch [13500/25000], Total Loss: 1.0606
# Epoch [13600/25000], Total Loss: 1.0731
# Epoch [13700/25000], Total Loss: 1.0462
# Epoch [13800/25000], Total Loss: 1.0601
# Epoch [13900/25000], Total Loss: 1.0940
# Epoch [14000/25000], Total Loss: 1.0400
# Epoch [14100/25000], Total Loss: 1.0726
# Epoch [14200/25000], Total Loss: 1.0349
# Epoch [14300/25000], Total Loss: 1.0305
# Epoch [14400/25000], Total Loss: 1.0880
# Epoch [14500/25000], Total Loss: 1.1390
# Epoch [14600/25000], Total Loss: 1.0629
# Epoch [14700/25000], Total Loss: 1.0531
# Epoch [14800/25000], Total Loss: 1.0487
# Epoch [14900/25000], Total Loss: 1.0714
# Epoch [15000/25000], Total Loss: 1.0454
# Epoch [15100/25000], Total Loss: 1.0539
# Epoch [15200/25000], Total Loss: 1.0436
# Epoch [15300/25000], Total Loss: 1.0394
# Epoch [15400/25000], Total Loss: 1.0398
# Epoch [15500/25000], Total Loss: 1.0609
# Epoch [15600/25000], Total Loss: 1.0876
# Epoch [15700/25000], Total Loss: 1.0165
# Epoch [15800/25000], Total Loss: 1.2796
# Epoch [15900/25000], Total Loss: 1.0936
# Epoch [16000/25000], Total Loss: 1.0728
# Epoch [16100/25000], Total Loss: 1.0609
# Epoch [16200/25000], Total Loss: 1.0535
# Epoch [16300/25000], Total Loss: 1.0491
# Epoch [16400/25000], Total Loss: 1.0472
# Epoch [16500/25000], Total Loss: 1.0430
# Epoch [16600/25000], Total Loss: 1.0443
# Epoch [16700/25000], Total Loss: 1.0430
# Epoch [16800/25000], Total Loss: 1.0406
# Epoch [16900/25000], Total Loss: 1.0359
# Epoch [17000/25000], Total Loss: 1.0365
# Epoch [17100/25000], Total Loss: 1.0445
# Epoch [17200/25000], Total Loss: 1.0379
# Epoch [17300/25000], Total Loss: 1.0390
# Epoch [17400/25000], Total Loss: 1.1258
# Epoch [17500/25000], Total Loss: 1.0325
# Epoch [17600/25000], Total Loss: 1.0304
# Epoch [17700/25000], Total Loss: 1.0366
# Epoch [17800/25000], Total Loss: 1.0306
# Epoch [17900/25000], Total Loss: 1.0702
# Epoch [18000/25000], Total Loss: 1.0383
# Epoch [18100/25000], Total Loss: 1.0361
# Epoch [18200/25000], Total Loss: 1.0374
# Epoch [18300/25000], Total Loss: 1.0286
# Epoch [18400/25000], Total Loss: 1.0237
# Epoch [18500/25000], Total Loss: 1.0221
# Epoch [18600/25000], Total Loss: 1.0470
# Epoch [18700/25000], Total Loss: 1.0304
# Early stopping at epoch 18705
# Restored model to epoch 15704 with best loss: 1.0121

# %%
# Print final losses
print("\nFinal Losses:")
print(f"Total Loss: {losses['total_loss'][-1]:.4f}")
print(f"Boundary Loss: {losses['boundary_loss'][-1]:.4f}")
print(f"Physics Loss: {losses['physics_loss'][-1]:.4f}")
# Out:
# Final Losses:
# Total Loss: 1.0209
# Boundary Loss: 0.0002
# Physics Loss: 1.0208

# %%
# Save KAN loss values to CSV
loss_df = pd.DataFrame(losses)
loss_df.to_csv('kan_loss_values.csv', index=False)

# %%
# Predict using the KAN model
y_kan = model(x_physics).detach().numpy()
kan_df = pd.DataFrame({'t': nn_t, 'theta': y_kan.squeeze()})
kan_df.to_csv('kan_results.csv', index=False)

# %%
# Plot both the numerical and KAN solutions before pruning
plt.figure(figsize=(12, 8))  
plt.plot(sol.t, sol.y[0], label='Numerical Solution')
plt.plot(nn_t, y_kan, label='KAN Solution')
plt.xlabel('t')
plt.ylabel('phi(t)')
plt.legend()
plt.title('Numerical vs KAN Solution')


plt.savefig('/kaggle/working/KAN_vs_numerical.png')
plt.show()

# %%
# Plot only the KAN solution before pruning
plt.figure(figsize=(12, 8))
plt.plot(nn_t, y_kan, label='KAN Solution')
plt.xlabel('t')
plt.ylabel('phi(t)')
plt.legend()
plt.title('KAN Solution Only')

plt.savefig('/kaggle/working/KAN_only.png')
plt.show()

# %%
# Plot the KAN grid before pruning
model.plot(scale=7)
plt.savefig('/kaggle/working/KAN_before_prune.png')

# %%
# Plot the KAN grid after automatic pruning
model_pruned=model.prune()
model_pruned(x_physics)
model_pruned.plot(scale=7)
plt.savefig('/kaggle/working/KAN_after_prune.png')
# Out:
# saving model version 0.1

# %%
# Predict using the KAN model
y_kan_prune = model_pruned(x_physics).detach().numpy()
kan_df_prune = pd.DataFrame({'t': nn_t, 'theta': y_kan_prune.squeeze()})
kan_df_prune.to_csv('kan_results_pruned.csv', index=False)

# Plot both the numerical and KAN solutions (KAN after pruningsdx)
plt.figure(figsize=(12, 8))  
plt.plot(sol.t, sol.y[0], label='Numerical Solution')
plt.plot(nn_t, y_kan_prune, label='KAN Solution (After Pruning)')
plt.xlabel('t')
plt.ylabel('phi(t)')
plt.legend()
plt.title('Numerical vs KAN Solution')
plt.savefig('/kaggle/working/KAN_vs_numerical_pruned.png')
plt.show()

# %%
# Plot only the KAN solution after pruning
plt.figure(figsize=(12, 8))
plt.plot(nn_t, y_kan_prune, label='KAN Solution')
plt.xlabel('t')
plt.ylabel('phi(t)')
plt.legend()
plt.title('KAN Solution Only (After Pruning)')
plt.savefig('/kaggle/working/KAN_only_pruned.png')
plt.show()
